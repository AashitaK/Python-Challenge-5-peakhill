# %% [markdown]
# # Python Challenge 5
# ## Aashita Kesarwani
# To decode the answer hidden in this challenge so as to move to the next level:
#
# http://www.pythonchallenge.com/pc/def/peak.html

# %%
import urllib.request
f = urllib.request.urlopen("http://www.pythonchallenge.com/pc/def/peak.html").readlines()
f
# Out:
# [b'<html>\n',
#  b'<head>\n',
#  b'  <title>peak hell</title>\n',
#  b'  <link rel="stylesheet" type="text/css" href="../style.css">\n',
#  b'</head>\n',
#  b'<body>\n',
#  b'<center>\n',
#  b'<img src="peakhell.jpg"/>\n',
#  b'<br><font color="#c0c0ff">\n',
#  b'pronounce it\n',
#  b'<br>\n',
#  b'<peakhell src="banner.p"/>\n',
#  b'</body>\n',
#  b'</html>\n',
#  b'\n',
#  b'<!-- peak hell sounds familiar ? -->\n']

# %%
print(f[11])
# Out:
# b'<peakhell src="banner.p"/>\n'

# %%
import pickle
pfile =  urllib.request.urlopen("http://www.pythonchallenge.com/pc/def/banner.p")
unpickled = pickle.load(pfile)

# %%
type(unpickled)
# Out:
# list

# %%
unpickled
# Out:
# [[(' ', 95)],
#  [(' ', 14), ('#', 5), (' ', 70), ('#', 5), (' ', 1)],
#  [(' ', 15), ('#', 4), (' ', 71), ('#', 4), (' ', 1)],
#  [(' ', 15), ('#', 4), (' ', 71), ('#', 4), (' ', 1)],
#  [(' ', 15), ('#', 4), (' ', 71), ('#', 4), (' ', 1)],
#  [(' ', 15), ('#', 4), (' ', 71), ('#', 4), (' ', 1)],
#  [(' ', 15), ('#', 4), (' ', 71), ('#', 4), (' ', 1)],
#  [(' ', 15), ('#', 4), (' ', 71), ('#', 4), (' ', 1)],
#  [(' ', 15), ('#', 4), (' ', 71), ('#', 4), (' ', 1)],
#  [(' ', 6),
#   ('#', 3),
#   (' ', 6),
#   ('#', 4),
#   (' ', 3),
#   ('#', 3),
#   (' ', 9),
#   ('#', 3),
#   (' ', 7),
#   ('#', 5),
#   (' ', 3),
#   ('#', 3),
#   (' ', 4),
#   ('#', 5),
#   (' ', 3),
#   ('#', 3),
#   (' ', 10),
#   ('#', 3),
#   (' ', 7),
#   ('#', 4),
#   (' ', 1)],
#  [(' ', 3),
#   ('#', 3),
#   (' ', 3),
#   ('#', 2),
#   (' ', 4),
#   ('#', 4),
#   (' ', 1),
#   ('#', 7),
#   (' ', 5),
#   ('#', 2),
#   (' ', 2),
#   ('#', 3),
#   (' ', 6),
#   ('#', 4),
#   (' ', 1),
#   ('#', 7),
# ...

# %%
for i in unpickled:
    for j in i:
        print(j[0]*j[1], end = "")
    print()
# Out:
#
#               #####                                                                      #####
#                ####                                                                       ####
#                ####                                                                       ####
#                ####                                                                       ####
#                ####                                                                       ####
#                ####                                                                       ####
#                ####                                                                       ####
#                ####                                                                       ####
#       ###      ####   ###         ###       #####   ###    #####   ###          ###       ####
#    ###   ##    #### #######     ##  ###      #### #######   #### #######     ###  ###     ####
# ...

# %% [markdown]
# Compact solution:

# %%
# Python 3
import urllib.request
banner =  urllib.request.urlopen("http://www.pythonchallenge.com/pc/def/banner.p")
import pickle
unpickled = pickle.load(banner)
for i in unpickled:
    for j in i:
        print(j[0]*j[1], end = "")
    print()
# Out:
#
#               #####                                                                      #####
#                ####                                                                       ####
#                ####                                                                       ####
#                ####                                                                       ####
#                ####                                                                       ####
#                ####                                                                       ####
#                ####                                                                       ####
#                ####                                                                       ####
#       ###      ####   ###         ###       #####   ###    #####   ###          ###       ####
#    ###   ##    #### #######     ##  ###      #### #######   #### #######     ###  ###     ####
# ...

# %% [markdown]
# ### Ans: channel
