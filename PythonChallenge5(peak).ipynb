# %%
http://www.pythonchallenge.com/pc/def/peak.html

# %%
import pickle

# %%
import urllib
f = urllib.urlopen("http://www.pythonchallenge.com/pc/def/peak.html", "r")
f.readlines()
# Out:
# ['<html>\n',
#  '<head>\n',
#  '  <title>peak hell</title>\n',
#  '  <link rel="stylesheet" type="text/css" href="../style.css">\n',
#  '</head>\n',
#  '<body>\n',
#  '<center>\n',
#  '<img src="peakhell.jpg"/>\n',
#  '<br><font color="#c0c0ff">\n',
#  'pronounce it\n',
#  '<br>\n',
#  '<peakhell src="banner.p"/>\n',
#  '</body>\n',
#  '</html>\n',
#  '\n',
#  '<!-- peak hell sounds familiar ? -->\n']

# %%
pfile =  urllib.urlopen("http://www.pythonchallenge.com/pc/def/banner.p", "r")
p = pickle.load(pfile)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-b6a924dbcb4f> in <module>()
# ----> 1 pfile =  urllib.urlopen("http://www.pythonchallenge.com/pc/def/banner.p", "r")
#       2 p = pickle.load(pfile)
#
# NameError: name 'urllib' is not defined

# %%
type(p)
# Out:
# list

# %%
p
# Out:
# [[(' ', 95)],
#  [(' ', 14), ('#', 5), (' ', 70), ('#', 5), (' ', 1)],
#  [(' ', 15), ('#', 4), (' ', 71), ('#', 4), (' ', 1)],
#  [(' ', 15), ('#', 4), (' ', 71), ('#', 4), (' ', 1)],
#  [(' ', 15), ('#', 4), (' ', 71), ('#', 4), (' ', 1)],
#  [(' ', 15), ('#', 4), (' ', 71), ('#', 4), (' ', 1)],
#  [(' ', 15), ('#', 4), (' ', 71), ('#', 4), (' ', 1)],
#  [(' ', 15), ('#', 4), (' ', 71), ('#', 4), (' ', 1)],
#  [(' ', 15), ('#', 4), (' ', 71), ('#', 4), (' ', 1)],
#  [(' ', 6),
#   ('#', 3),
#   (' ', 6),
#   ('#', 4),
#   (' ', 3),
#   ('#', 3),
#   (' ', 9),
#   ('#', 3),
#   (' ', 7),
#   ('#', 5),
#   (' ', 3),
#   ('#', 3),
#   (' ', 4),
#   ('#', 5),
#   (' ', 3),
#   ('#', 3),
#   (' ', 10),
#   ('#', 3),
#   (' ', 7),
#   ('#', 4),
#   (' ', 1)],
#  [(' ', 3),
#   ('#', 3),
#   (' ', 3),
#   ('#', 2),
#   (' ', 4),
#   ('#', 4),
#   (' ', 1),
#   ('#', 7),
#   (' ', 5),
#   ('#', 2),
#   (' ', 2),
#   ('#', 3),
#   (' ', 6),
#   ('#', 4),
#   (' ', 1),
#   ('#', 7),
# ...

# %%
pfile =  urllib.urlopen("http://www.pythonchallenge.com/pc/def/banner.p", "rb")
p = pickle.load(pfile)
p
# Out:
# [[(' ', 95)],
#  [(' ', 14), ('#', 5), (' ', 70), ('#', 5), (' ', 1)],
#  [(' ', 15), ('#', 4), (' ', 71), ('#', 4), (' ', 1)],
#  [(' ', 15), ('#', 4), (' ', 71), ('#', 4), (' ', 1)],
#  [(' ', 15), ('#', 4), (' ', 71), ('#', 4), (' ', 1)],
#  [(' ', 15), ('#', 4), (' ', 71), ('#', 4), (' ', 1)],
#  [(' ', 15), ('#', 4), (' ', 71), ('#', 4), (' ', 1)],
#  [(' ', 15), ('#', 4), (' ', 71), ('#', 4), (' ', 1)],
#  [(' ', 15), ('#', 4), (' ', 71), ('#', 4), (' ', 1)],
#  [(' ', 6),
#   ('#', 3),
#   (' ', 6),
#   ('#', 4),
#   (' ', 3),
#   ('#', 3),
#   (' ', 9),
#   ('#', 3),
#   (' ', 7),
#   ('#', 5),
#   (' ', 3),
#   ('#', 3),
#   (' ', 4),
#   ('#', 5),
#   (' ', 3),
#   ('#', 3),
#   (' ', 10),
#   ('#', 3),
#   (' ', 7),
#   ('#', 4),
#   (' ', 1)],
#  [(' ', 3),
#   ('#', 3),
#   (' ', 3),
#   ('#', 2),
#   (' ', 4),
#   ('#', 4),
#   (' ', 1),
#   ('#', 7),
#   (' ', 5),
#   ('#', 2),
#   (' ', 2),
#   ('#', 3),
#   (' ', 6),
#   ('#', 4),
#   (' ', 1),
#   ('#', 7),
# ...

# %%
len(p)
# Out:
# 23

# %%
for i in p:
    s = 0
    for j in i:
        s += j[1]
    print(s)
#     for j in i:
#         print(sum(j[1]))
# Out:
# 95
# 95
# 95
# 95
# 95
# 95
# 95
# 95
# 95
# 95
# 95
# 95
# 95
# 95
# 95
# 95
# 95
# 95
# 95
# 95
# 95
# 95
# 95

# %%
for i in p:
    for j in i:
        print(j[0]*j[1])
# Out:
#
#
# #####
#
# #####
#
#
# ####
#
# ####
#
#
# ####
#
# ####
#
#
# ####
#
# ####
#
#
# ####
#
# ####
#
#
# ####
#
# ####
#
#
# ####
#
# ####
#
#
# ####
#
# ####
#
#
# ###
#
# ####
#
# ###
#
# ###
#
# #####
#
# ###
#
# #####
#
# ###
#
# ###
#
# ####
#
#
# ###
#
# ##
#
# ####
#
# #######
#
# ##
#
# ###
#
# ####
#
# #######
#
# ####
#
# #######
#
# ###
#
# ###
#
# ####
#
#
# ###
#
# ###
#
# #####
#
# ####
#
# ###
#
# ####
#
# #####
#
# ####
#
# #####
#
# ####
#
# ###
#
# ###
#
# ####
#
#
# ###
#
# ####
#
# ####
#
# ###
#
# ###
#
# ####
#
# ####
#
# ####
#
# ####
#
# ###
#
# ####
#
# ####
#
#
# ###
#
# ####
#
# ####
#
# ###
#
# ####
#
# ####
#
# ####
#
# ####
#
# ###
#
# ###
#
# ####
#
# ####
#
# ####
#
# ####
#
# ##
#
# ###
#
# ####
#
# ####
#
# ####
#
# ####
#
# ####
#
# ###
#
# ####
#
# ####
#
# ####
#
# ####
#
# ##########
#
# ####
#
# ####
#
# ####
#
# ####
#
# ##############
#
# ####
#
# ####
#
# ####
#
# ####
#
# ###
#
# ####
#
# ####
#
# ####
#
# ####
#
# ####
#
# ####
#
# ####
#
# ...

# %%
import numpy as np
pn = np.array(p)

# %%
pn
# Out:
# array([[(' ', 95)], [(' ', 14), ('#', 5), (' ', 70), ('#', 5), (' ', 1)],
#        [(' ', 15), ('#', 4), (' ', 71), ('#', 4), (' ', 1)],
#        [(' ', 15), ('#', 4), (' ', 71), ('#', 4), (' ', 1)],
#        [(' ', 15), ('#', 4), (' ', 71), ('#', 4), (' ', 1)],
#        [(' ', 15), ('#', 4), (' ', 71), ('#', 4), (' ', 1)],
#        [(' ', 15), ('#', 4), (' ', 71), ('#', 4), (' ', 1)],
#        [(' ', 15), ('#', 4), (' ', 71), ('#', 4), (' ', 1)],
#        [(' ', 15), ('#', 4), (' ', 71), ('#', 4), (' ', 1)],
#        [(' ', 6), ('#', 3), (' ', 6), ('#', 4), (' ', 3), ('#', 3), (' ', 9), ('#', 3), (' ', 7), ('#', 5), (' ', 3), ('#', 3), (' ', 4), ('#', 5), (' ', 3), ('#', 3), (' ', 10), ('#', 3), (' ', 7), ('#', 4), (' ', 1)],
# ...

# %%
a = np.chararray((23,95))
for i, l in enumerate(p):
    for j, t in enumerate(l):
        #print(l,t)
        #print(t[0])
        a[i,j] = t[0]
a
# Out:
# chararray([['', '', '', ..., '', '', ''],
#        ['', '#', '', ..., '', '', ''],
#        ['', '#', '', ..., '', '', ''],
#        ...,
#        ['', '#', '', ..., '', '', ''],
#        ['', '#', '', ..., '', '', ''],
#        ['', '', '', ..., '', '', '']],
#       dtype='|S1')

# %%
np.empty([23,95])
# Out:
# array([[  5.96949244e-316,   5.91288200e-316,   5.95247049e-316, ...,
#           5.96547035e-316,   5.96547272e-316,   5.96547509e-316],
#        [  5.96547746e-316,   5.96547983e-316,   5.96548220e-316, ...,
#           5.96611065e-316,   5.96611303e-316,   5.96611540e-316],
#        [  5.96612014e-316,   5.96612251e-316,   5.96612488e-316, ...,
#           5.94085955e-316,   5.94086192e-316,   5.94086430e-316],
#        ...,
#        [  5.95300408e-316,   5.95300645e-316,   5.95300882e-316, ...,
#           5.96490118e-316,   5.96490355e-316,   5.96490593e-316],
#        [  5.96490830e-316,   5.96491067e-316,   5.96491304e-316, ...,
#           5.94490457e-316,   5.94494488e-316,   5.94497097e-316],
#        [  3.85221798e-316,   3.85225118e-316,   3.85221561e-316, ...,
#           5.95018751e-316,   5.95018988e-316,   5.95019225e-316]])

# %%
for i in p:
    for j in i:
        print("".join(j[0]*j[1]))
# Out:
#
#
# #####
#
# #####
#
#
# ####
#
# ####
#
#
# ####
#
# ####
#
#
# ####
#
# ####
#
#
# ####
#
# ####
#
#
# ####
#
# ####
#
#
# ####
#
# ####
#
#
# ####
#
# ####
#
#
# ###
#
# ####
#
# ###
#
# ###
#
# #####
#
# ###
#
# #####
#
# ###
#
# ###
#
# ####
#
#
# ###
#
# ##
#
# ####
#
# #######
#
# ##
#
# ###
#
# ####
#
# #######
#
# ####
#
# #######
#
# ###
#
# ###
#
# ####
#
#
# ###
#
# ###
#
# #####
#
# ####
#
# ###
#
# ####
#
# #####
#
# ####
#
# #####
#
# ####
#
# ###
#
# ###
#
# ####
#
#
# ###
#
# ####
#
# ####
#
# ###
#
# ###
#
# ####
#
# ####
#
# ####
#
# ####
#
# ###
#
# ####
#
# ####
#
#
# ###
#
# ####
#
# ####
#
# ###
#
# ####
#
# ####
#
# ####
#
# ####
#
# ###
#
# ###
#
# ####
#
# ####
#
# ####
#
# ####
#
# ##
#
# ###
#
# ####
#
# ####
#
# ####
#
# ####
#
# ####
#
# ###
#
# ####
#
# ####
#
# ####
#
# ####
#
# ##########
#
# ####
#
# ####
#
# ####
#
# ####
#
# ##############
#
# ####
#
# ####
#
# ####
#
# ####
#
# ###
#
# ####
#
# ####
#
# ####
#
# ####
#
# ####
#
# ####
#
# ####
#
# ...

# %%
import sys
sys.stdout = open("goat.txt", "w")
print ("test sys.stdout")
for i in p:
    for j in i:
        print(j[0]*j[1])

# %%
for k in range(95):
    print("#", end = "")
# Out:
# ###############################################################################################

# %%
# Python 3
import urllib.request
banner =  urllib.request.urlopen("http://www.pythonchallenge.com/pc/def/banner.p")
import pickle
unpickled = pickle.load(banner)
for i in p:
    for j in i:
        print(j[0]*j[1], end = "")
    print()
# Out:
#
#               #####                                                                      #####
#                ####                                                                       ####
#                ####                                                                       ####
#                ####                                                                       ####
#                ####                                                                       ####
#                ####                                                                       ####
#                ####                                                                       ####
#                ####                                                                       ####
#       ###      ####   ###         ###       #####   ###    #####   ###          ###       ####
#    ###   ##    #### #######     ##  ###      #### #######   #### #######     ###  ###     ####
# ...

# %%
# ans = channel
# solution: http://www.pythonchallenge.com/pcc/def/channel.html

# %%
# Python 3
import urllib.request
banner =  urllib.request.urlopen("http://www.pythonchallenge.com/pc/def/banner.p")
import pickle
unpickled = pickle.load(banner)
for linelist in unpickled:
    print("".join(ch * count for ch, count in linelist))
# Out:
#
#               #####                                                                      #####
#                ####                                                                       ####
#                ####                                                                       ####
#                ####                                                                       ####
#                ####                                                                       ####
#                ####                                                                       ####
#                ####                                                                       ####
#                ####                                                                       ####
#       ###      ####   ###         ###       #####   ###    #####   ###          ###       ####
#    ###   ##    #### #######     ##  ###      #### #######   #### #######     ###  ###     ####
# ...

# %%
# Python 3
import urllib.request
banner =  urllib.request.urlopen("http://www.pythonchallenge.com/pc/def/banner.p")
import pickle
unpickled = pickle.load(banner)
print("\n".join(["".join(ch * count for ch, count in linelist) for linelist in unpickled]))
# Out:
#
#               #####                                                                      #####
#                ####                                                                       ####
#                ####                                                                       ####
#                ####                                                                       ####
#                ####                                                                       ####
#                ####                                                                       ####
#                ####                                                                       ####
#                ####                                                                       ####
#       ###      ####   ###         ###       #####   ###    #####   ###          ###       ####
#    ###   ##    #### #######     ##  ###      #### #######   #### #######     ###  ###     ####
# ...
